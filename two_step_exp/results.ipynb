# %%
import sys
sys.path.append('/home/shiftpub/Dynamic_AMM/two_step_exp')
from metric_plot import subplot_comparison
import numpy as np
import polars as pl

# %%
output_dir = '/home/shiftpub/Dynamic_AMM/two_step_exp/output/two_step_metrics.parquet'
for metric in ['fee_revenue', 'pool_value', 'arbitrageur_revenue', 'accounting_profit']:
    subplot_comparison(output_dir, metric=metric)
