# %%
"""
amm: Dictionary with Key = asset, Value = amt of asset
trade: Tuple with (Asset to sell, asset to collect, amt of asset to sell) 
    - from the AMMs pov
fee_type: fee structure to be implemented on trade
"""
# Out:
# '\namm: Dictionary with Key = asset, Value = amt of asset\ntrade: Tuple with (Asset to sell, asset to collect, amt of asset to sell) \n    - from the AMMs pov\nfee_type: fee structure to be implemented on trade\n'

# %%
import math
import numpy as np
import random
from scipy.stats import truncnorm
from scipy import integrate
import matplotlib.pyplot as plt

# %%
def quote(amm, trade):
    """
    AB/L^2 = 1 doesn't actually need the bisection solver as there will always be a closed form solution
    These are the closed form solutions for each trade 
    """
    if trade[0] == "L":
        return np.sqrt(amm["A"] * amm["B"])
    elif trade[0] == "A":
        new_A = (amm["L"]**2) / amm["B"]
        new_B = (amm["L"]**2) / new_A
        return new_A, new_B
    else:
        new_B = (amm["L"]**2) / amm["A"]
        new_A = (amm["L"]**2) / new_B
        return new_B, new_A

# %%
def fee_calc(amm, trade, type):
    
    if type == "percentage":
        return 0.003
    
    elif type == "tiered":
        mean, sigma = 10, 5
        if trade[2] < (mean - sigma): return 0.0005
        elif trade[2] > (mean +  sigma): return 0.01
        return 0.003
    
    elif type == "naive triangle": 
        mean, sigma = 10, 5
        if trade[2] > (mean - sigma) and trade[2] < (mean + sigma): return 0.003
        elif trade[2] < (mean - sigma): return 0.01
        return 0.0005
    
    elif type == "triangle":
        # get delta x to set upper limit
        delta_x = amm[trade[0]] - quote(amm, trade)[0]
        delta_y = quote(amm, trade)[1] - amm[trade[1]]
        f, m, X, Y = 0.003, -1, amm[trade[0]], amm[trade[1]]
        
        delta_val = ((Y + delta_y) / (X - max(f, delta_x))) - (Y / X)
        def func(x):
            return f + m * x
    
        try:
            return (f * delta_val) + (0.5 * m * (delta_val)**2) * 100000
        except ZeroDivisionError:
            return 0

# %%
def trade_calc(amm, trade, fee_type):
    # Add the amount of assets given to amm to AMM
    amm[trade[1]] += trade[2]
    
    # Calculate the fees to be assessed on the trade
    if fee_type == "triangle": 
        fee = fee_calc(amm, trade, "triangle")
        amm[trade[0]] = quote(amm, trade)[0] - fee
    else: 
        fee = (quote(amm, trade)[0] - amm[trade[0]]) * fee_calc(amm, trade, fee_type)
        amm[trade[0]] = quote(amm, trade)[0] * (1 - fee_calc(amm, trade, fee_type))
    
    # Update amm for asset going out 
        # This could be wrong, let me know
    return fee, amm

# %%
def geometric_brownian_motion(mu, sigma, S0, T, N, dt):
    """
    Generate geometric brownian motion.

    Parameters:
        mu (float): Drift coefficient.
        sigma (float): Diffusion coefficient.
        S0 (float): Initial value.
        T (float): Terminal time.
        N (int): Number of time steps.
        dt (float): Time step size.

    Returns:
        numpy.ndarray: Simulated GBM path.
    """
    t = np.linspace(0, T, N)
    W = np.random.standard_normal(size=N)
    W = np.cumsum(W) * np.sqrt(dt)  # Standard Brownian motion
    X = (mu - 0.5 * sigma**2) * t + sigma * W 
    S = S0 * np.exp(X)  # Geometric Brownian motion
    return S

# Parameters
mu = 0  # Drift coefficient
sigma = 0.0351  # Diffusion coefficient
S0 = 45000  # Initial value
T = 1.0  # Terminal time
N = 480  # Number of time steps
dt = T / N  # Time step size

# Generate GBM path
gbm_path = geometric_brownian_motion(mu, sigma, S0, T, N, dt)

# Plot GBM path
plt.plot(np.linspace(0, T, N), gbm_path)
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Geometric Brownian Motion')
plt.grid(True)
plt.show()

# %%
AMM = {
    "A": 10000,
    "B": 10000,
    "L": 10000
}

mean = 10  # Mean
sigma = 5  # Standard deviation
a = (0 - mean) / sigma  # Lower bound
b = (10000 - mean) / sigma  # Upper bound

# Create a frozen distribution object
trade_sizes = truncnorm(a, b, loc=mean, scale=sigma)

values_list = (trade_sizes.rvs(size=480)).tolist()

exchange_rate = []
assets = ["A", "B"]
choices = [0, 1]
feesA = []
feesB = []
ratiosA = []
ratiosB = []
vols = []
unrealized_rtrns, unrealized_vol = [], []

for j in range(1000):
    trade_sizes = truncnorm(a, b, loc=mean, scale=sigma)
    values_list = (trade_sizes.rvs(size=480)).tolist()
    underlying = geometric_brownian_motion(0, 0.0351, 2800, 1.0, 480, T/N)
    port_val = []

    fees_collected = {
    "A": 0,
    "B": 0,
    "FA": 0,
    "FB": 0
    }
    
    for i, item in enumerate(values_list):
        traded = random.choice(choices)
        trade = (assets[traded], assets[(traded + 1) % len(assets)], item)
        exchange_rate.append(AMM["A"] / AMM["B"])
        fee, AMM = trade_calc(AMM, trade, "triangle")
        fees_collected[assets[traded]] += (fee * ((AMM["A"] / AMM[assets[traded]]) * underlying[i]))
        fees_collected["F" + assets[traded]] += 0.003
        port_val.append(((AMM["A"]/AMM["L"]) * underlying[i]) + (fees_collected["A"] + fees_collected["B"]))

    feesA.append(-1 * fees_collected["A"])
    feesB.append(-1 * fees_collected["B"])
    ratiosA.append((((-1 * fees_collected["A"] - fees_collected["FA"]) / np.std(exchange_rate)) / 10000))
    ratiosB.append((((-1 * fees_collected["B"] - fees_collected["FB"]) / np.std(exchange_rate)) / 10000))
    vols.append(np.std(exchange_rate) * 100)
    unrealized_rtrns.append((port_val[-1] / port_val[0]) - 1)
    unrealized_vol.append(np.std(port_val))

# %%
print(feesA)
# Out:
# [47179.48691750724, 41225.25399903458, 45296.74613830558, 42289.820395456554, 52710.1599078701, 47704.90918556157, 47069.76644644264, 47143.17847486557, 49192.16210533841, 47168.0992971011, 48671.815992764605, 46507.63811362217, 44553.59222678091, 41427.947151656444, 46522.62219091447, 47227.98224341211, 46043.337959445555, 38667.823976610634, 47397.32565876847, 42372.0868754693, 42752.64204589081, 52662.36500499927, 45275.30203617656, 42066.962202873634, 44465.454299201614, 44040.220378313454, 46542.506177625066, 50166.6370277698, 44718.809220261246, 43359.61544417614, 40246.48179172417, 37987.922647727566, 42204.20928625968, 37152.333251415854, 48394.78270692215, 44058.27277270469, 43483.5572813888, 43595.48251497205, 45371.65968477978, 44142.85170947804, 48054.007719485475, 39218.706604927924, 42313.835102465564, 34214.65981769525, 38644.24877554188, 41834.368118284125, 39484.275656096856, 40907.364606859504, 40594.445059737685, 44583.35551758759, 42574.82554459547, 41181.412694893006, 42778.000238481705, 44372.689130571256, 38105.13166821168, 37849.031795703755, 35552.94594159719, 37063.36118226843, 41607.567719053885, 36559.89412692101, 46700.073217295045, 40158.541482204164, 49153.71159897794, 47334.30617314732, 41095.31769822809, 46043.96152623867, 45482.40499692642, 46342.83817649536, 45702.237564459785, 46750.27536184609, 43167.12518298504, 43352.802142296205, 41993.35035278067, 43204.36364739496, 44879.45629871157, 45985.023062422166, 40353.54703569649, 40686.77713913965, 42297.55577163516, 39072.20602582591, 39215.08235379144, 46554.63437357927, 40504.437078762036, 38617.28704154479, 40210.035305488, 45879.99748956184, 37677.45714642275, 40370.27540926151, 43364.55888324154, 45971.87587214788, 49221.14817890547, 44188.945845541, 48631.61399419756, 41740.52872988079, 46506.1927998584, 43307.985800707764, 44934.140560446605, 42476.23428709991, 48541.24068498589, 42089.17980324056, 32779.13839924679, 32769.541778000494, 42828.0696469358, 35839.29756014124, 34875.985223492, 37843.20162316967, 42030.84812204977, 46432.461794778916, 42397.95916135326, 52474.49732937651, 46388.9679117682, 48565.99846561663, 48386.30485554623, 47351.371214224, 46045.07089486125, 45223.42649653448, 46438.820215665146, 49109.20550774435, 44830.01718844698, 49214.06261643335, 47975.33601565776, 50703.497027841666, 41643.82424552504, 48527.29306257076, 46373.175687526535, 43105.94763679178, 44699.09125941954, 39023.009038847886, 42918.483118048825, 50045.11868174776, 47873.75003925554, 47017.81579954395, 41760.74444115785, 38887.3803446167, 38857.23816125684, 41192.01766349178, 43119.32340228662, 38768.36239194172, 42390.14901273654, 42412.63000409871, 47708.009445603464, 47468.24316114322, 42657.170297933066, 39023.99352827524, 39860.98384904665, 43371.386041584105, 39320.180054815384, 44674.47167538825, 46894.182162800105, 35024.44988217981, 35170.936869270605, 42147.36856629406, 41952.96831052848, 42969.53702609473, 36138.133047064715, 38887.11559920186, 33655.83278536205, 40488.53724957465, 37869.91918039883, 38638.37215631307, 41665.98038018473, 44058.53574529985, 45377.9224807383, 45908.730701224995, 43047.775561652896, 44189.164523364554, 47542.97186616078, 38993.500695978895, 38649.233032473, 39764.90597797403, 34889.52317472553, 42931.98485072205, 47679.429971627855, 35170.791559426914, 41800.39182630148, 44206.09744658722, 41975.19051352202, 50705.35148233984, 46573.89703720429, 45970.68361241928, 42646.56272660176, 42492.69626961104, 42969.654434416065, 42430.87295021032, 50552.744769123376, 35673.80841944052, 44938.0002916059, 39227.55550372661, 48866.98393767501, 40974.061614336075, 49108.49934787906, 37274.09145541587, 41816.8157041224, 37308.62025985046, 38882.92426127803, 38021.81631259872, 43563.8411114829, 44765.1942694497, 37068.419813945635, 49074.989513583576, 50365.80110588791, 55468.98828582193, 43938.76664884929, 42775.56615378252, 48027.64183397166, 43572.29838900644, 39529.0823127714, 41340.466770900595, 38582.28275760 ...

# %%
plt.plot(unrealized[-480:])

# %%
print(np.mean(unrealized_vol))
print(np.mean(unrealized_rtrns))
# Out:
# 23107.080560045983
# 26.874848376265632

# %%
for i in range(len(exchange_rate)):
    if i % 100 == 0:
        print("Exchange rate after", i, "iterations:", exchange_rate[i])
# Out:
# Exchange rate after 0 iterations: 1.0
# Exchange rate after 100 iterations: 0.9865502298967297
# Exchange rate after 200 iterations: 0.9812748860487335
# Exchange rate after 300 iterations: 0.938542160458284
# Exchange rate after 400 iterations: 0.9541923669761991
# Exchange rate after 500 iterations: 0.921957744161832
# Exchange rate after 600 iterations: 0.9313760164052736
# Exchange rate after 700 iterations: 0.9172418101078655
# Exchange rate after 800 iterations: 0.9723536438963045
# Exchange rate after 900 iterations: 0.9660169582940491
# Exchange rate after 1000 iterations: 0.9420979496122459
# Exchange rate after 1100 iterations: 0.9771307395963982
# Exchange rate after 1200 iterations: 0.9959425278960201
# Exchange rate after 1300 iterations: 1.0124237472965647
# Exchange rate after 1400 iterations: 1.016837628507093
# Exchange rate after 1500 iterations: 1.011154928211634
# Exchange rate after 1600 iterations: 0.9860120919285993
# Exchange rate after 1700 iterations: 1.0027542315184923
# Exchange rate after 1800 iterations: 1.0001464220151357
# Exchange rate after 1900 iterations: 0.9821195906091919
# Exchange rate after 2000 iterations: 0.9607359073164193
# Exchange rate after 2100 iterations: 0.9835841337031825
# Exchange rate after 2200 iterations: 0.9932950489755988
# Exchange rate after 2300 iterations: 0.9812576031982839
# Exchange rate after 2400 iterations: 0.9869667762246492
# Exchange rate after 2500 iterations: 1.0238288560164477
# Exchange rate after 2600 iterations: 1.0144920272842277
# Exchange rate after 2700 iterations: 1.0189525940052966
# Exchange rate after 2800 iterations: 1.031191866736611
# Exchange rate after 2900 iterations: 1.0171405826884892
# Exchange rate after 3000 iterations: 1.0460160435236463
# Exchange rate after 3100 iterations: 1.0375117368147018
# Exchange rate after 3200 iterations: 1.027140063058526
# Exchange rate after 3300 iterations: 1.0244112950429063
# Exchange rate after 3400 iterations: 1.0175062347532449
# Exchange rate after 3500 iterations: 0.9797080043457154
# Exchange rate after 3600 iterations: 0.9746139447823807
# Exchange rate after 3700 iterations: 0.9863329421867092
# Exchange rate after 3800 iterations: 1.0372286444058028
# Exchange rate after 3900 iterations: 1.0006097263188927
# Exchange rate after 4000 iterations: 0.9930480798083607
# Exchange rate after 4100 iterations: 1.0257138608608336
# Exchange rate after 4200 iterations: 1.0158235349630795
# Exchange rate after 4300 iterations: 1.0074072223643344
# Exchange rate after 4400 iterations: 1.0206582070778576
# Exchange rate after 4500 iterations: 1.002441662017846
# Exchange rate after 4600 iterations: 1.001455984569773
# Exchange rate after 4700 iterations: 1.0404308631801324
# Exchange rate after 4800 iterations: 1.047831047956743
# Exchange rate after 4900 iterations: 1.0834872162089242
# Exchange rate after 5000 iterations: 1.0568698598564956
# Exchange rate after 5100 iterations: 1.0470702809608712
# Exchange rate after 5200 iterations: 1.0252508156090878
# Exchange rate after 5300 iterations: 1.0269725533436191
# Exchange rate after 5400 iterations: 1.023321372748625
# Exchange rate after 5500 iterations: 1.0220490964953006
# Exchange rate after 5600 iterations: 0.9793568988380675
# Exchange rate after 5700 iterations: 0.9991162530565587
# Exchange rate after 5800 iterations: 0.9968179876044039
# Exchange rate after 5900 iterations: 1.0164128113624562
# Exchange rate after 6000 iterations: 1.0076958235840057
# Exchange rate after 6100 iterations: 1.0166007797733603
# Exchange rate after 6200 iterations: 0.9909665715503599
# Exchange rate after 6300 iterations: 1.000614509829912
# Exchange rate after 6400 iterations: 0.9951507387235226
# Exchange rate after 6500 iterations: 0.9529091566323069
# Exchange rate after 6600 iterations: 0.9282883215195809
# Exchange rate after 6700 iterations: 0.9811867678336194
# Exchange rate after 6800 iterations: 0.9359173879736057
# Exchange rate after 6900 iterations: 0.9630205858029295
# Exchange rate after 7000 iterations: 0.9831254475236456
# Exchange rate after 7100 iterations: 0.9756913812525748
# Exchange rate after 7200 iterations: 0.9910844792799195
# Exchange rate after 7300 iterations: 0.9841316801075404
# Exchange rate after 7400 iterations: 0.9695988346195312
# Exchange rate after 7500 iterations: 0.9514632663972934
# Exchange rate after 7600 iterations: 0.9613343685357356
# Exchange rate after 7700 iterations: 0.9725590964618483
# Exchange rate after 7800 iterations: 0.9894182128224844
# Exchange rate after 7900 iterations: 1.0038199289094767
# Exchange rate after 8000 iterations: 1.0328501967948907
# Exchange rate after 8100 iterations: 1.0361380465036432
# Exchange rate after 8200 iterations: 1.0574171946347386
# Exchange rate after 8300 iterations: 1.0240398230995524
# Exchange rate after 8400 iterations: 0.9931587216635536
# Exchange rate after 8500 iterations: 0.9902614479669157
# Exchange rate after 8600 iterations: 1.0759564736353133
# Exchange rate after 8700 iterations: 1.0443431253769597
# Exchange rate after 8800 iterations: 1.0539555213253005
# Exchange rate after 8900 iterations: 1.022183010519
# Exchange rate after 9000 iterations: 1.0390511681431718
# Exchange rate after 9100 iterations: 1.0526865026907455
# Exchange rate after 9200 iterations: 1.0063678210978186
# Exchange rate after 9300 iterations: 1.0200029655944158
# Exchange rate after 9400 iterations: 0.9909897074158257
# Exchange rate after 9500 iterations: 0.9804818381399557
# Exchange rate after 9600 iterations: 0.9850242711552437
# Exchange rate after 9700 iterations: 1.0049377020419472
# Exchange rate after 9800 iterations: 1.0435751380832046
# Exchange rate after 9900 iterations: 1.021967516095346
# Exchange rate after 10000 iterations: 0.9965828122118766
# Exchange rate after 10100 iterations: 1.0021200156842989
# Exchange rate after 10200 iterations: 0.9759020701874088
# Exchange rate after 10300 iterations: 0.9766598839620639
# Exchange rate after 10400 iterations: 0.9687778876723069
# Exchange rate after 10500 iterations: 0.9752900340791801
# Exchange rate after 10600 iterations: 1.0100875891127543
# Exchange rate after 10700 iterations: 0.9783356319360081
# Exchange rate after 10800 iterations: 0.9958205991622656
# Exchange rate after 10900 iterations: 1.0131710122672182
# Exchange rate after 11000 iterations: 1.017028376650168
# Exchange rate after 11100 iterations: 1.03578497736481
# Exchange rate after 11200 iterations: 1.0222178147909287
# Exchange rate after 11300 iterations: 1.011294450969052
# Exchange rate after 11400 iterations: 1.0110460756994617
# Exchange rate after 11500 iterations: 1.061456512030466
# Exchange rate after 11600 iterations: 1.0653044505746394
# Exchange rate after 11700 iterations: 1.0672756099323104
# Exchange rate after 11800 iterations: 1.09774777020191
# Exchange rate after 11900 iterations: 1.088167334648507
# Exchange rate after 12000 iterations: 1.0798194100302563
# Exchange rate after 12100 iterations: 1.0673007281175482
# Exchange rate after 12200 iterations: 1.060319995184234
# Exchange rate after 12300 iterations: 1.0391391437442867
# Exchange rate after 12400 iterations: 1.0211889569731034
# Exchange rate after 12500 iterations: 1.0105307607961482
# Exchange rate after 12600 iterations: 1.0223839441720197
# Exchange rate after 12700 iterations: 0.9810454605434699
# Exchange rate after 12800 iterations: 0.9885801084878916
# Exchange rate after 12900 iterations: 1.0010307882707439
# Exchange rate after 13000 iterations: 1.0006581502660865
# Exchange rate after 13100 iterations: 0.9930961034858431
# Exchange rate after 13200 iterations: 0.9705540717451521
# Exchange rate after 13300 iterations: 0.9573256445890007
# Exchange rate after 13400 iterations: 0.9522407842892118
# Exchange rate after 13500 iterations: 0.9559943740497521
# Exchange rate after 13600 iterations: 0.9847042711125562
# Exchange rate after 13700 iterations: 0.979899226088747
# Exchange rate after 13800 iterations: 0.9947485958867298
# Exchange rate after 13900 iterations: 0.9886168746431346
# Exchange rate after 14000 iterations: 0.958497718413289
# Exchange rate after 14100 iterations: 0.9319975890483652
# Exchange rate after 14200 iterations: 0.9342367641403773
# Exchange rate after 14300 iterations: 0.9541550181626509
# Exchange rate after 14400 iterations: 0.9420014630527859
# Exchange rate after 14500 iterations: 0.942574894756443
# Exchange rate after 14600 iterations: 0.920240788152309
# Exchange rate after 14700 iterations: 0.8863990575732378
# Exchange rate after 14800 iterations: 0.861428937191638
# Exchange rate after 14900 iterations: 0.8667693478662378
# Exchange rate after 15000 iterations: 0.917040648005012
# Exchange rate after 15100 iterations: 0.9129553026703121
# Exchange rate after 15200 iterations: 0.9200231831488234
# Exchange rate after 15300 iterations: 0.9016913345553141
# Exchange rate after 15400 iterations: 0.903685139388896
# Exchange rate after 15500 iterations: 0.8975860053767689
# Exchange rate after 15600 iterations: 0.9141055215412678
# Exchange rate after 15700 iterations: 0.9275080409162373
# Exchange rate after 15800 iterations: 0.9381486541918646
# Exchange rate after 15900 iterations: 0.9047253377635636
# Exchange rate after 16000 iterations: 0.9008130699262884
# Exchange rate after 16100 iterations: 0.8859331856928132
# Exchange rate after 16200 iterations: 0.8808026591252859
# Exchange rate after 16300 iterations: 0.9139849060925949
# Exchange rate after 16400 iterations: 0.9268707246051067
# Exchange rate after 16500 iterations: 0.9324154080282263
# Exchange rate after 16600 iterations: 0.9827014702006771
# Exchange rate after 16700 iterations: 0.9823915269737804
# Exchange rate after 16800 iterations: 0.9426259639859019
# Exchange rate after 16900 iterations: 0.9696460301796841
# Exchange rate after 17000 iterations: 0.9749440700552291
# Exchange rate after 17100 iterations: 0.9700075405801446
# Exchange rate after 17200 iterations: 0.9951722897143221
# Exchange rate after 17300 iterations: 1.0023016174724801
# Exchange rate after 17400 iterations: 1.0172611802282374
# Exchange rate after 17500 iterations: 0.9758141191541607
# Exchange rate after 17600 iterations: 0.998062372410795
# Exchange rate after 17700 iterations: 1.017633943285634
# Exchange rate after 17800 iterations: 1.018176950066683
# Exchange rate after 17900 iterations: 1.0335633399407602
# Exchange rate after 18000 iterations: 1.0370406780407717
# Exchange rate after 18100 iterations: 1.0105609223124103
# Exchange rate after 18200 iterations: 0.9980607882393252
# Exchange rate after 18300 iterations: 0.9863883302494265
# Exchange rate after 18400 iterations: 0.9826435787400172
# Exchange rate after 18500 iterations: 0.9456002006617635
# Exchange rate after 18600 iterations: 0.9279026715284968
# Exchange rate after 18700 iterations: 0.9361016736204578
# Exchange rate after 18800 iterations: 0.9523624947468872
# Exchange rate after 18900 iterations: 0.9575282196422814
# Exchange rate after 19000 iterations: 0.962361326205246
# Exchange rate after 19100 iterations: 0.9526663240406674
# Exchange rate after 19200 iterations: 0.9386578784350146
# Exchange rate after 19300 iterations: 0.9606441612021764
# Exchange rate after 19400 iterations: 1.0090153274498241
# Exchange rate after 19500 iterations: 0.9859228024243459
# Exchange rate after 19600 iterations: 0.9742294896719726
# Exchange rate after 19700 iterations: 0.9742750370619222
# Exchange rate after 19800 iterations: 0.9569879837715044
# Exchange rate after 19900 iterations: 0.9550603735841392
# Exchange rate after 20000 iterations: 0.9992229361430868
# Exchange rate after 20100 iterations: 1.02459366206549
# Exchange rate after 20200 iterations: 1.0109067876391844
# Exchange rate after 20300 iterations: 1.023774903746456
# Exchange rate after 20400 iterations: 1.0198649633129167
# Exchange rate after 20500 iterations: 1.0380135745696504
# Exchange rate after 20600 iterations: 1.0637000776988912
# Exchange rate after 20700 iterations: 1.029205082728119
# Exchange rate after 20800 iterations: 1.0430704176865528
# Exchange rate after 20900 iterations: 1.0587278658174908
# Exchange rate after 21000 iterations: 1.0402599130924115
# Exchange rate after 21100 iterations: 1.0028632435558311
# Exchange rate after 21200 iterations: 1.012357270575225
# Exchange rate after 21300 iterations: 1.0075149872578961
# Exchange rate after 21400 iterations: 0.96118065695746
# Exchange rate after 21500 iterations: 1.0081345273612237
# Exchange rate after 21600 iterations: 1.0251368090917299
# Exchange rate after 21700 iterations: 0.9862807822359437
# Exchange rate after 21800 iterations: 0.973808347711123
# Exchange rate after 21900 iterations: 0.9549250501643045
# Exchange rate after 22000 iterations: 0.9680709778859617
# Exchange rate after 22100 iterations: 0.980053024084682
# Exchange rate after 22200 iterations: 0.9818254530739727
# Exchange rate after 22300 iterations: 0.9769230117625558
# Exchange rate after 22400 iterations: 0.955695648081672
# Exchange rate after 22500 iterations: 0.9388781645524262
# Exchange rate after 22600 iterations: 0.9452638216612191
# Exchange rate after 22700 iterations: 0.9434567808630685
# Exchange rate after 22800 iterations: 0.9021349166280966
# Exchange rate after 22900 iterations: 0.9205040819424193
# Exchange rate after 23000 iterations: 0.9277397557923862
# Exchange rate after 23100 iterations: 0.9795369014898725
# Exchange rate after 23200 iterations: 1.0067473444315487
# Exchange rate after 23300 iterations: 1.0583376382192602
# Exchange rate after 23400 iterations: 1.116855390702977
# Exchange rate after 23500 iterations: 1.0940604736422836
# Exchange rate after 23600 iterations: 1.1013908258747707
# Exchange rate after 23700 iterations: 1.0878220763694777
# Exchange rate after 23800 iterations: 1.0612644790405288
# Exchange rate after 23900 iterations: 1.071546263288358
# Exchange rate after 24000 iterations: 1.073758255582644
# Exchange rate after 24100 iterations: 1.0781084791326405
# Exchange rate after 24200 iterations: 1.0992372724897368
# Exchange rate after 24300 iterations: 1.0467357045610644
# Exchange rate after 24400 iterations: 1.0451228890433342
# Exchange rate after 24500 iterations: 1.0660769371179109
# Exchange rate after 24600 iterations: 1.0661895795379996
# Exchange rate after 24700 iterations: 1.0430734167131248
# Exchange rate after 24800 iterations: 1.0565408884429677
# Exchange rate after 24900 iterations: 1.0517477822496268
# Exchange rate after 25000 iterations: 1.065650299192482
# Exchange rate after 25100 iterations: 1.0827892161238772
# Exchange rate after 25200 iterations: 1.1009198436991374
# Exchange rate after 25300 iterations: 1.066178247931574
# Exchange rate after 25400 iterations: 1.0527848335502488
# Exchange rate after 25500 iterations: 1.056725917137561
# Exchange rate after 25600 iterations: 1.0522207171089062
# Exchange rate after 25700 iterations: 1.0388814539526225
# Exchange rate after 25800 iterations: 1.0922001687670297
# Exchange rate after 25900 iterations: 1.0946516691881365
# Exchange rate after 26000 iterations: 1.1031428619850283
# Exchange rate after 26100 iterations: 1.0587826433446013
# Exchange rate after 26200 iterations: 1.0679409201235364
# Exchange rate after 26300 iterations: 1.0918917683738594
# Exchange rate after 26400 iterations: 1.0510088795731904
# Exchange rate after 26500 iterations: 1.0064004188531965
# Exchange rate after 26600 iterations: 0.9975444101667506
# Exchange rate after 26700 iterations: 1.0085949118797857
# Exchange rate after 26800 iterations: 1.0165901681759868
# Exchange rate after 26900 iterations: 1.0103114384432874
# Exchange rate after 27000 iterations: 1.0224626030877713
# Exchange rate after 27100 iterations: 1.0559368504508475
# Exchange rate after 27200 iterations: 1.0852426390210808
# Exchange rate after 27300 iterations: 1.0519420105979602
# Exchange rate after 27400 iterations: 1.0601818278469906
# Exchange rate after 27500 iterations: 1.0770622061408561
# Exchange rate after 27600 iterations: 1.0378526090934588
# Exchange rate after 27700 iterations: 1.0156787120841717
# Exchange rate after 27800 iterations: 1.039649393838195
# Exchange rate after 27900 iterations: 1.04321408077509
# Exchange rate after 28000 iterations: 1.034079159895948
# Exchange rate after 28100 iterations: 1.053093571595887
# Exchange rate after 28200 iterations: 1.0446220368137287
# Exchange rate after 28300 iterations: 1.0708545981047979
# Exchange rate after 28400 iterations: 1.0526303574627218
# Exchange rate after 28500 iterations: 1.0537533548344271
# Exchange rate after 28600 iterations: 1.0477506202993723
# Exchange rate after 28700 iterations: 1.0194291563507694
# Exchange rate after 28800 iterations: 1.0320959088020516
# Exchange rate after 28900 iterations: 1.0325011888129172
# Exchange rate after 29000 iterations: 1.051858602070728
# Exchange rate after 29100 iterations: 1.0328251972481712
# Exchange rate after 29200 iterations: 0.9980286403167574
# Exchange rate after 29300 iterations: 1.0330495830173396
# Exchange rate after 29400 iterations: 1.0274369839165742
# Exchange rate after 29500 iterations: 1.0377969346482518
# Exchange rate after 29600 iterations: 1.024885137487022
# Exchange rate after 29700 iterations: 1.0231647922535358
# Exchange rate after 29800 iterations: 1.0105567557597461
# Exchange rate after 29900 iterations: 0.99248346535765
# Exchange rate after 30000 iterations: 1.0232359691335486
# Exchange rate after 30100 iterations: 1.0285508240424073
# Exchange rate after 30200 iterations: 1.020791424847386
# Exchange rate after 30300 iterations: 0.9790745138981697
# Exchange rate after 30400 iterations: 0.9731174601461767
# Exchange rate after 30500 iterations: 0.9936667552004963
# Exchange rate after 30600 iterations: 1.026811409556797
# Exchange rate after 30700 iterations: 1.0246742969977147
# Exchange rate after 30800 iterations: 1.0567197929481502
# Exchange rate after 30900 iterations: 1.0578381417603258
# Exchange rate after 31000 iterations: 1.054820421433608
# Exchange rate after 31100 iterations: 1.0479099585055658
# Exchange rate after 31200 iterations: 1.0443929458806211
# Exchange rate after 31300 iterations: 1.0496007845604272
# Exchange rate after 31400 iterations: 1.027443500601691
# Exchange rate after 31500 iterations: 1.0170783524986127
# Exchange rate after 31600 iterations: 1.0442935044170392
# Exchange rate after 31700 iterations: 1.0682226843890004
# Exchange rate after 31800 iterations: 1.0718771338892392
# Exchange rate after 31900 iterations: 1.1050699412784057
# Exchange rate after 32000 iterations: 1.0650979420524385
# Exchange rate after 32100 iterations: 1.0329344355395924
# Exchange rate after 32200 iterations: 1.056604889135456
# Exchange rate after 32300 iterations: 1.0517468800469287
# Exchange rate after 32400 iterations: 1.067926660690241
# Exchange rate after 32500 iterations: 1.0490574997877162
# Exchange rate after 32600 iterations: 1.0602840187340434
# Exchange rate after 32700 iterations: 1.0568339065929255
# Exchange rate after 32800 iterations: 1.046828021737138
# Exchange rate after 32900 iterations: 1.025789183813168
# Exchange rate after 33000 iterations: 1.007629094216909
# Exchange rate after 33100 iterations: 1.0248858236494558
# Exchange rate after 33200 iterations: 1.0429666388098933
# Exchange rate after 33300 iterations: 1.013288095223048
# Exchange rate after 33400 iterations: 0.9947570684981941
# Exchange rate after 33500 iterations: 1.025166613645252
# Exchange rate after 33600 iterations: 1.0196192577475967
# Exchange rate after 33700 iterations: 1.0122213915332516
# Exchange rate after 33800 iterations: 0.984549136839118
# Exchange rate after 33900 iterations: 0.9789078020953516
# Exchange rate after 34000 iterations: 1.0240466637520407
# Exchange rate after 34100 iterations: 1.0633290367170825
# Exchange rate after 34200 iterations: 1.0631958154751409
# Exchange rate after 34300 iterations: 1.057271635281357
# Exchange rate after 34400 iterations: 1.0458126448746095
# Exchange rate after 34500 iterations: 1.044788068522371
# Exchange rate after 34600 iterations: 1.072898500925291
# Exchange rate after 34700 iterations: 1.0637668902306028
# Exchange rate after 34800 iterations: 1.080017681566778
# Exchange rate after 34900 iterations: 1.0688214047489055
# Exchange rate after 35000 iterations: 1.0284491028554608
# Exchange rate after 35100 iterations: 0.9919826593063426
# Exchange rate after 35200 iterations: 0.9995948653083617
# Exchange rate after 35300 iterations: 1.0022657598522275
# Exchange rate after 35400 iterations: 0.9797979855569064
# Exchange rate after 35500 iterations: 0.9836970276202002
# Exchange rate after 35600 iterations: 0.9839260290769929
# Exchange rate after 35700 iterations: 0.9696397560013399
# Exchange rate after 35800 iterations: 0.986465268283255
# Exchange rate after 35900 iterations: 0.9733221184143137
# Exchange rate after 36000 iterations: 0.9570090561411267
# Exchange rate after 36100 iterations: 0.9494685818894356
# Exchange rate after 36200 iterations: 0.9442523329961703
# Exchange rate after 36300 iterations: 0.9067387644904241
# Exchange rate after 36400 iterations: 0.9348707542800964
# Exchange rate after 36500 iterations: 0.9741263397830664
# Exchange rate after 36600 iterations: 0.9868713727934079
# Exchange rate after 36700 iterations: 0.9922115271262776
# Exchange rate after 36800 iterations: 0.9977181817738373
# Exchange rate after 36900 iterations: 1.004509637634631
# Exchange rate after 37000 iterations: 1.0032312429614607
# Exchange rate after 37100 iterations: 0.9562012737760128
# Exchange rate after 37200 iterations: 0.9777257104987748
# Exchange rate after 37300 iterations: 0.9647267965344027
# Exchange rate after 37400 iterations: 0.9407511342712512
# Exchange rate after 37500 iterations: 0.9587499714593378
# Exchange rate after 37600 iterations: 0.9794097072493935
# Exchange rate after 37700 iterations: 0.9923419727165668
# Exchange rate after 37800 iterations: 0.9655493970791776
# Exchange rate after 37900 iterations: 1.009905555012457
# Exchange rate after 38000 iterations: 1.0302783828930995
# Exchange rate after 38100 iterations: 1.0363939328403267
# Exchange rate after 38200 iterations: 1.038111933329283
# Exchange rate after 38300 iterations: 1.0453973438083075
# Exchange rate after 38400 iterations: 1.0419191307141114
# Exchange rate after 38500 iterations: 1.0426748788669171
# Exchange rate after 38600 iterations: 1.0357894967559336
# Exchange rate after 38700 iterations: 1.0070114518593203
# Exchange rate after 38800 iterations: 0.9973324954162993
# Exchange rate after 38900 iterations: 0.9707011401595828
# Exchange rate after 39000 iterations: 0.9786751429733693
# Exchange rate after 39100 iterations: 1.0168140273048956
# Exchange rate after 39200 iterations: 1.0182064213429607
# Exchange rate after 39300 iterations: 1.0608944818362058
# Exchange rate after 39400 iterations: 1.0649176096038597
# Exchange rate after 39500 iterations: 1.0579431536808204
# Exchange rate after 39600 iterations: 1.0587793904938982
# Exchange rate after 39700 iterations: 1.0477061023826506
# Exchange rate after 39800 iterations: 1.0802152120368507
# Exchange rate after 39900 iterations: 1.0713393928872883
# Exchange rate after 40000 iterations: 1.0893126470308585
# Exchange rate after 40100 iterations: 1.0910220733373603
# Exchange rate after 40200 iterations: 1.0763560589185526
# Exchange rate after 40300 iterations: 1.0568178438264102
# Exchange rate after 40400 iterations: 0.9972007195951499
# Exchange rate after 40500 iterations: 1.0122434541330039
# Exchange rate after 40600 iterations: 0.9906254172361119
# Exchange rate after 40700 iterations: 1.0671960450064
# Exchange rate after 40800 iterations: 1.0490947615499875
# Exchange rate after 40900 iterations: 1.0389708773655173
# Exchange rate after 41000 iterations: 1.0391856789060314
# Exchange rate after 41100 iterations: 1.0469519622942365
# Exchange rate after 41200 iterations: 1.031077094951697
# Exchange rate after 41300 iterations: 1.0248010925678979
# Exchange rate after 41400 iterations: 1.0167602415484869
# Exchange rate after 41500 iterations: 0.9942674198806567
# Exchange rate after 41600 iterations: 0.971433310294476
# Exchange rate after 41700 iterations: 0.9616304323640077
# Exchange rate after 41800 iterations: 0.9623197010947665
# Exchange rate after 41900 iterations: 0.9487329665486538
# Exchange rate after 42000 iterations: 0.9946995019841821
# Exchange rate after 42100 iterations: 0.9595805065842806
# Exchange rate after 42200 iterations: 0.9759389184256633
# Exchange rate after 42300 iterations: 0.9530774295922902
# Exchange rate after 42400 iterations: 0.9357149014913414
# Exchange rate after 42500 iterations: 0.9352794844110309
# Exchange rate after 42600 iterations: 0.9331393461006318
# Exchange rate after 42700 iterations: 0.9256511898240812
# Exchange rate after 42800 iterations: 0.9802138751141195
# Exchange rate after 42900 iterations: 0.9769265627805159
# Exchange rate after 43000 iterations: 0.9591203385748147
# Exchange rate after 43100 iterations: 0.9750645218792554
# Exchange rate after 43200 iterations: 0.9547797516351896
# Exchange rate after 43300 iterations: 0.9714944549936446
# Exchange rate after 43400 iterations: 0.9629010255737122
# Exchange rate after 43500 iterations: 0.9721408293955021
# Exchange rate after 43600 iterations: 1.0064501070474503
# Exchange rate after 43700 iterations: 1.0254025122033446
# Exchange rate after 43800 iterations: 1.047788336191055
# Exchange rate after 43900 iterations: 1.0533030517921258
# Exchange rate after 44000 iterations: 1.0827948201018436
# Exchange rate after 44100 iterations: 1.0995451140434835
# Exchange rate after 44200 iterations: 1.0585076435535095
# Exchange rate after 44300 iterations: 1.0498407363794355
# Exchange rate after 44400 iterations: 1.072038933387266
# Exchange rate after 44500 iterations: 1.0540549171326719
# Exchange rate after 44600 iterations: 1.0971039082146614
# Exchange rate after 44700 iterations: 1.0735641971722176
# Exchange rate after 44800 iterations: 1.0893349737996352
# Exchange rate after 44900 iterations: 1.0944833289631277
# Exchange rate after 45000 iterations: 1.0818598480951263
# Exchange rate after 45100 iterations: 1.0532955011788363
# Exchange rate after 45200 iterations: 1.0286942581153369
# Exchange rate after 45300 iterations: 1.0333393167105245
# Exchange rate after 45400 iterations: 1.0032318212303246
# Exchange rate after 45500 iterations: 1.0291075462132986
# Exchange rate after 45600 iterations: 1.049136294641427
# Exchange rate after 45700 iterations: 1.028990569668275
# Exchange rate after 45800 iterations: 1.0208735745746302
# Exchange rate after 45900 iterations: 1.0473408753577194
# Exchange rate after 46000 iterations: 1.0341614671224668
# Exchange rate after 46100 iterations: 1.0545967798932177
# Exchange rate after 46200 iterations: 1.087730186092565
# Exchange rate after 46300 iterations: 1.1051657643170454
# Exchange rate after 46400 iterations: 1.0799439058120706
# Exchange rate after 46500 iterations: 1.0370716040522727
# Exchange rate after 46600 iterations: 1.0203718448810457
# Exchange rate after 46700 iterations: 1.0752166936683405
# Exchange rate after 46800 iterations: 1.0589440585331478
# Exchange rate after 46900 iterations: 1.0785357599479628
# Exchange rate after 47000 iterations: 1.035258653380598
# Exchange rate after 47100 iterations: 1.0358911401621025
# Exchange rate after 47200 iterations: 1.0588729256205764
# Exchange rate after 47300 iterations: 1.0163935282056253
# Exchange rate after 47400 iterations: 1.0051271349847475
# Exchange rate after 47500 iterations: 0.9870390194155082
# Exchange rate after 47600 iterations: 0.9949353361398713
# Exchange rate after 47700 iterations: 0.9942996858716189
# Exchange rate after 47800 iterations: 0.9777672491148456
# Exchange rate after 47900 iterations: 0.9739911840212808
# Exchange rate after 48000 iterations: 0.9768748770763441
# Exchange rate after 48100 iterations: 0.9592732470734966
# Exchange rate after 48200 iterations: 0.9538188177809074
# Exchange rate after 48300 iterations: 0.9755575791426538
# Exchange rate after 48400 iterations: 0.9941144216381196
# Exchange rate after 48500 iterations: 0.9859851753973071
# Exchange rate after 48600 iterations: 0.9975079359014991
# Exchange rate after 48700 iterations: 1.0068581575459006
# Exchange rate after 48800 iterations: 1.024281288823031
# Exchange rate after 48900 iterations: 1.0249674290147015
# Exchange rate after 49000 iterations: 1.0406201539805888
# Exchange rate after 49100 iterations: 1.002062334268346
# Exchange rate after 49200 iterations: 1.017050422259193
# Exchange rate after 49300 iterations: 1.0159197169664926
# Exchange rate after 49400 iterations: 1.026625561597605
# Exchange rate after 49500 iterations: 1.0047141111047553
# Exchange rate after 49600 iterations: 1.030642442063052
# Exchange rate after 49700 iterations: 1.0353631145323867
# Exchange rate after 49800 iterations: 1.021072423180599
# Exchange rate after 49900 iterations: 1.09908017394994
# Exchange rate after 50000 iterations: 1.091793412100909
# Exchange rate after 50100 iterations: 1.0725921201998876
# Exchange rate after 50200 iterations: 1.108882571618992
# Exchange rate after 50300 iterations: 1.081067182526969
# Exchange rate after 50400 iterations: 1.103071887292938
# Exchange rate after 50500 iterations: 1.116506181161289
# Exchange rate after 50600 iterations: 1.0885208979693035
# Exchange rate after 50700 iterations: 1.0964599318514237
# Exchange rate after 50800 iterations: 1.116092318825208
# Exchange rate after 50900 iterations: 1.123049376754644
# Exchange rate after 51000 iterations: 1.1010953499369924
# Exchange rate after 51100 iterations: 1.1123536989474077
# Exchange rate after 51200 iterations: 1.0547277471697438
# Exchange rate after 51300 iterations: 1.0463836052031295
# Exchange rate after 51400 iterations: 1.0324447335840086
# Exchange rate after 51500 iterations: 1.0524970204481143
# Exchange rate after 51600 iterations: 1.063784596511448
# Exchange rate after 51700 iterations: 1.0527614901173423
# Exchange rate after 51800 iterations: 1.01941826170368
# Exchange rate after 51900 iterations: 1.0496197938350145
# Exchange rate after 52000 iterations: 1.0912377559257627
# Exchange rate after 52100 iterations: 1.0764944104449914
# Exchange rate after 52200 iterations: 1.0750974754726603
# Exchange rate after 52300 iterations: 1.0967775652381513
# Exchange rate after 52400 iterations: 1.104564243898364
# Exchange rate after 52500 iterations: 1.069431874391923
# Exchange rate after 52600 iterations: 1.1150375324026447
# Exchange rate after 52700 iterations: 1.0992634239835002
# Exchange rate after 52800 iterations: 1.1069070818839264
# Exchange rate after 52900 iterations: 1.0823298935786012
# Exchange rate after 53000 iterations: 1.1184595994197626
# Exchange rate after 53100 iterations: 1.0991393778526137
# Exchange rate after 53200 iterations: 1.1443035206584378
# Exchange rate after 53300 iterations: 1.1139444160186962
# Exchange rate after 53400 iterations: 1.0830960500886548
# Exchange rate after 53500 iterations: 1.0916098983813929
# Exchange rate after 53600 iterations: 1.099900817223659
# Exchange rate after 53700 iterations: 1.076710913378493
# Exchange rate after 53800 iterations: 1.1126686781219577
# Exchange rate after 53900 iterations: 1.1136877571747337
# Exchange rate after 54000 iterations: 1.0940180952921208
# Exchange rate after 54100 iterations: 1.1190739131819607
# Exchange rate after 54200 iterations: 1.0965957695358641
# Exchange rate after 54300 iterations: 1.0792081984221535
# Exchange rate after 54400 iterations: 1.0766965842187097
# Exchange rate after 54500 iterations: 1.0752995287539673
# Exchange rate after 54600 iterations: 1.0417040673812312
# Exchange rate after 54700 iterations: 1.0034285929844415
# Exchange rate after 54800 iterations: 1.0011399638481846
# Exchange rate after 54900 iterations: 1.015849671682015
# Exchange rate after 55000 iterations: 1.0308061217983329
# Exchange rate after 55100 iterations: 1.0338530157296903
# Exchange rate after 55200 iterations: 0.9923413992578467
# Exchange rate after 55300 iterations: 0.9590010788226139
# Exchange rate after 55400 iterations: 0.9408188904517072
# Exchange rate after 55500 iterations: 0.9255038758594301
# Exchange rate after 55600 iterations: 0.9697900794404906
# Exchange rate after 55700 iterations: 0.9854530377475761
# Exchange rate after 55800 iterations: 0.984225673145411
# Exchange rate after 55900 iterations: 0.970413181192837
# Exchange rate after 56000 iterations: 0.9647008841200599
# Exchange rate after 56100 iterations: 0.9760941672321694
# Exchange rate after 56200 iterations: 0.9898080285693022
# Exchange rate after 56300 iterations: 1.0072947919588777
# Exchange rate after 56400 iterations: 0.9661980901663305
# Exchange rate after 56500 iterations: 0.9721373289108897
# Exchange rate after 56600 iterations: 1.005396412845126
# Exchange rate after 56700 iterations: 1.0407611989318482
# Exchange rate after 56800 iterations: 1.066414084692641
# Exchange rate after 56900 iterations: 1.0713440779070342
# Exchange rate after 57000 iterations: 1.0587433143165044
# Exchange rate after 57100 iterations: 1.0471974401664308
# Exchange rate after 57200 iterations: 1.0308899670293648
# Exchange rate after 57300 iterations: 1.0182778309656888
# Exchange rate after 57400 iterations: 1.021818894278868
# Exchange rate after 57500 iterations: 1.0031936848531198
# Exchange rate after 57600 iterations: 1.0256031918389774
# Exchange rate after 57700 iterations: 1.0455249784713638
# Exchange rate after 57800 iterations: 1.0344344742390417
# Exchange rate after 57900 iterations: 1.0139903867085351
# Exchange rate after 58000 iterations: 1.0264138481957257
# Exchange rate after 58100 iterations: 1.074746616931557
# Exchange rate after 58200 iterations: 1.0552619307962174
# Exchange rate after 58300 iterations: 1.0526331379169551
# Exchange rate after 58400 iterations: 1.0508407547194267
# Exchange rate after 58500 iterations: 1.0310525184963115
# Exchange rate after 58600 iterations: 1.0263345197063303
# Exchange rate after 58700 iterations: 1.0065827811975694
# Exchange rate after 58800 iterations: 0.9929682290758233
# Exchange rate after 58900 iterations: 0.9907442822139694
# Exchange rate after 59000 iterations: 0.9842169322037237
# Exchange rate after 59100 iterations: 0.9981178546499945
# Exchange rate after 59200 iterations: 1.0334760874747302
# Exchange rate after 59300 iterations: 1.0376277478494147
# Exchange rate after 59400 iterations: 1.0824555960685918
# Exchange rate after 59500 iterations: 1.0854579858285769
# Exchange rate after 59600 iterations: 1.0577277276102075
# Exchange rate after 59700 iterations: 1.0319120096538748
# Exchange rate after 59800 iterations: 1.0556891532641348
# Exchange rate after 59900 iterations: 1.0577135605354362
# Exchange rate after 60000 iterations: 1.0261264229667069
# Exchange rate after 60100 iterations: 1.0284931230092602
# Exchange rate after 60200 iterations: 0.9938578580788672
# Exchange rate after 60300 iterations: 1.0001954932425425
# Exchange rate after 60400 iterations: 0.9902944943010498
# Exchange rate after 60500 iterations: 0.9692697735375566
# Exchange rate after 60600 iterations: 0.9826172581839465
# Exchange rate after 60700 iterations: 1.0027802391268616
# Exchange rate after 60800 iterations: 1.0098703738017256
# Exchange rate after 60900 iterations: 1.0165018016785317
# Exchange rate after 61000 iterations: 1.0193506891705462
# Exchange rate after 61100 iterations: 1.0362286223564434
# Exchange rate after 61200 iterations: 1.0409299535197378
# Exchange rate after 61300 iterations: 1.018039492721869
# Exchange rate after 61400 iterations: 1.0263380812707625
# Exchange rate after 61500 iterations: 1.0173433212312213
# Exchange rate after 61600 iterations: 0.9960060046414654
# Exchange rate after 61700 iterations: 1.015018213396773
# Exchange rate after 61800 iterations: 1.042532453021883
# Exchange rate after 61900 iterations: 1.0420507738075406
# Exchange rate after 62000 iterations: 1.0578840031965402
# Exchange rate after 62100 iterations: 1.0827904869611982
# Exchange rate after 62200 iterations: 1.093799495663776
# Exchange rate after 62300 iterations: 1.0888132007706086
# Exchange rate after 62400 iterations: 1.0806544088964198
# Exchange rate after 62500 iterations: 1.06851982877755
# Exchange rate after 62600 iterations: 1.0776644795403272
# Exchange rate after 62700 iterations: 1.0677233081755972
# Exchange rate after 62800 iterations: 1.0471809604690399
# Exchange rate after 62900 iterations: 1.045146804668208
# Exchange rate after 63000 iterations: 1.0640291884590938
# Exchange rate after 63100 iterations: 1.0551576936130722
# Exchange rate after 63200 iterations: 1.0272648481085698
# Exchange rate after 63300 iterations: 1.0158764105757467
# Exchange rate after 63400 iterations: 0.9897792408386635
# Exchange rate after 63500 iterations: 0.9895427308089471
# Exchange rate after 63600 iterations: 0.9736901238452641
# Exchange rate after 63700 iterations: 0.9838909854840712
# Exchange rate after 63800 iterations: 0.9377026906705198
# Exchange rate after 63900 iterations: 0.9775159409097284
# Exchange rate after 64000 iterations: 0.9802349884916662
# Exchange rate after 64100 iterations: 0.993866437878172
# Exchange rate after 64200 iterations: 0.9881156881050576
# Exchange rate after 64300 iterations: 1.012725250533796
# Exchange rate after 64400 iterations: 0.968824772783848
# Exchange rate after 64500 iterations: 0.9694654056848042
# Exchange rate after 64600 iterations: 0.9939565479085608
# Exchange rate after 64700 iterations: 0.9899106985543268
# Exchange rate after 64800 iterations: 1.0283535166020503
# Exchange rate after 64900 iterations: 1.038173918424544
# Exchange rate after 65000 iterations: 1.0091551841334172
# Exchange rate after 65100 iterations: 0.9914938916120448
# Exchange rate after 65200 iterations: 1.033511854354008
# Exchange rate after 65300 iterations: 1.030654447693393
# Exchange rate after 65400 iterations: 1.0596304237712666
# Exchange rate after 65500 iterations: 1.030290469219604
# Exchange rate after 65600 iterations: 1.019650265018741
# Exchange rate after 65700 iterations: 1.0210568547418095
# Exchange rate after 65800 iterations: 1.0326788977028671
# Exchange rate after 65900 iterations: 1.0348547785875923
# Exchange rate after 66000 iterations: 0.9982685002385958
# Exchange rate after 66100 iterations: 0.9899401909009882
# Exchange rate after 66200 iterations: 1.0125196846041742
# Exchange rate after 66300 iterations: 1.008763192178345
# Exchange rate after 66400 iterations: 1.010117503691026
# Exchange rate after 66500 iterations: 1.0160124580826644
# Exchange rate after 66600 iterations: 1.0494927573111825
# Exchange rate after 66700 iterations: 1.042903620726258
# Exchange rate after 66800 iterations: 1.0727147798276195
# Exchange rate after 66900 iterations: 1.0982256045368832
# Exchange rate after 67000 iterations: 1.0734379535940561
# Exchange rate after 67100 iterations: 1.0876945314540685
# Exchange rate after 67200 iterations: 1.0525195498762376
# Exchange rate after 67300 iterations: 1.0735623859145385
# Exchange rate after 67400 iterations: 1.0815471413762645
# Exchange rate after 67500 iterations: 1.0762795564093601
# Exchange rate after 67600 iterations: 1.0488531975731323
# Exchange rate after 67700 iterations: 1.0525568033015966
# Exchange rate after 67800 iterations: 1.0609389839047936
# Exchange rate after 67900 iterations: 1.0935708301223654
# Exchange rate after 68000 iterations: 1.0665854849580834
# Exchange rate after 68100 iterations: 1.0216441167665358
# Exchange rate after 68200 iterations: 1.037487252878439
# Exchange rate after 68300 iterations: 1.0578585059299392
# Exchange rate after 68400 iterations: 1.0746904766286207
# Exchange rate after 68500 iterations: 1.108121154159627
# Exchange rate after 68600 iterations: 1.1090581342478787
# Exchange rate after 68700 iterations: 1.0809241434311818
# Exchange rate after 68800 iterations: 1.02891832163359
# Exchange rate after 68900 iterations: 1.031439530427896
# Exchange rate after 69000 iterations: 1.048356364224232
# Exchange rate after 69100 iterations: 1.0268996906262409
# Exchange rate after 69200 iterations: 1.0516152011516422
# Exchange rate after 69300 iterations: 1.0422373633937885
# Exchange rate after 69400 iterations: 1.0104756929289984
# Exchange rate after 69500 iterations: 0.9829708143100487
# Exchange rate after 69600 iterations: 0.9705263363993951
# Exchange rate after 69700 iterations: 0.9757353445983575
# Exchange rate after 69800 iterations: 0.9750838175786817
# Exchange rate after 69900 iterations: 0.9975659172855241
# Exchange rate after 70000 iterations: 1.0188012745222617
# Exchange rate after 70100 iterations: 0.9883135656109854
# Exchange rate after 70200 iterations: 0.9797215806983937
# Exchange rate after 70300 iterations: 0.9797862821305863
# Exchange rate after 70400 iterations: 0.9791999921632767
# Exchange rate after 70500 iterations: 0.9486119307722352
# Exchange rate after 70600 iterations: 0.9412170972634393
# Exchange rate after 70700 iterations: 0.9447260721670252
# Exchange rate after 70800 iterations: 0.9749611420573482
# Exchange rate after 70900 iterations: 0.9615577267810335
# Exchange rate after 71000 iterations: 0.9624877175209655
# Exchange rate after 71100 iterations: 0.9531968492239131
# Exchange rate after 71200 iterations: 0.9652665489216571
# Exchange rate after 71300 iterations: 0.9722825981680052
# Exchange rate after 71400 iterations: 0.9513527125937777
# Exchange rate after 71500 iterations: 0.9702957049830941
# Exchange rate after 71600 iterations: 0.9687765678519051
# Exchange rate after 71700 iterations: 0.9653289216016998
# Exchange rate after 71800 iterations: 0.9872718920649791
# Exchange rate after 71900 iterations: 0.9727559155101078
# Exchange rate after 72000 iterations: 0.9780383826717481
# Exchange rate after 72100 iterations: 0.9958522520143417
# Exchange rate after 72200 iterations: 0.9864483700169928
# Exchange rate after 72300 iterations: 0.9764539339261165
# Exchange rate after 72400 iterations: 0.9762204596437347
# Exchange rate after 72500 iterations: 0.9427730792857315
# Exchange rate after 72600 iterations: 0.945737244126494
# Exchange rate after 72700 iterations: 0.9651802511041606
# Exchange rate after 72800 iterations: 0.9570714603291782
# Exchange rate after 72900 iterations: 0.9674276790019022
# Exchange rate after 73000 iterations: 1.006557967434964
# Exchange rate after 73100 iterations: 0.9840875290532308
# Exchange rate after 73200 iterations: 0.9821712179245179
# Exchange rate after 73300 iterations: 1.0066851710639948
# Exchange rate after 73400 iterations: 0.9801364001821878
# Exchange rate after 73500 iterations: 0.9812341391263218
# Exchange rate after 73600 iterations: 0.9485131184487917
# Exchange rate after 73700 iterations: 0.9377300704460179
# Exchange rate after 73800 iterations: 0.9312819785437061
# Exchange rate after 73900 iterations: 0.9148237020939913
# Exchange rate after 74000 iterations: 0.9297420193287824
# Exchange rate after 74100 iterations: 0.8898117343827332
# Exchange rate after 74200 iterations: 0.9167151352317965
# Exchange rate after 74300 iterations: 0.8970928445899403
# Exchange rate after 74400 iterations: 0.9296312053047827
# Exchange rate after 74500 iterations: 0.9599524813595592
# Exchange rate after 74600 iterations: 0.9444539272526522
# Exchange rate after 74700 iterations: 0.9579456143917592
# Exchange rate after 74800 iterations: 0.9109097497304298
# Exchange rate after 74900 iterations: 0.9266305962690216
# Exchange rate after 75000 iterations: 0.9485259383862753
# Exchange rate after 75100 iterations: 0.939852654079647
# Exchange rate after 75200 iterations: 0.9411311057167059
# Exchange rate after 75300 iterations: 0.9331484955858882
# Exchange rate after 75400 iterations: 0.95796098543921
# Exchange rate after 75500 iterations: 0.9679583246897147
# Exchange rate after 75600 iterations: 0.9780648237853161
# Exchange rate after 75700 iterations: 0.9374867513815799
# Exchange rate after 75800 iterations: 0.9545920963795614
# Exchange rate after 75900 iterations: 0.9834669541556487
# Exchange rate after 76000 iterations: 0.9809120133240027
# Exchange rate after 76100 iterations: 0.980431544184132
# Exchange rate after 76200 iterations: 0.9824131994647772
# Exchange rate after 76300 iterations: 0.94537172175793
# Exchange rate after 76400 iterations: 0.9684322657289587
# Exchange rate after 76500 iterations: 0.9898624881356793
# Exchange rate after 76600 iterations: 1.0138021542560314
# Exchange rate after 76700 iterations: 1.0357592093426773
# Exchange rate after 76800 iterations: 1.018765460330455
# Exchange rate after 76900 iterations: 0.9915683428808929
# Exchange rate after 77000 iterations: 0.9852608895498258
# Exchange rate after 77100 iterations: 0.9719374879411355
# Exchange rate after 77200 iterations: 0.9952680291167192
# Exchange rate after 77300 iterations: 1.0171986917982911
# Exchange rate after 77400 iterations: 0.9647778530793594
# Exchange rate after 77500 iterations: 0.9733827694172574
# Exchange rate after 77600 iterations: 0.9513331340366169
# Exchange rate after 77700 iterations: 0.9609525762865933
# Exchange rate after 77800 iterations: 0.9562484726870979
# Exchange rate after 77900 iterations: 0.9464076431601612
# Exchange rate after 78000 iterations: 0.9393230475302479
# Exchange rate after 78100 iterations: 0.9549111984702664
# Exchange rate after 78200 iterations: 0.9032536334261487
# Exchange rate after 78300 iterations: 0.919383285284848
# Exchange rate after 78400 iterations: 0.9302906151333864
# Exchange rate after 78500 iterations: 0.9378643283343695
# Exchange rate after 78600 iterations: 0.9544485793634978
# Exchange rate after 78700 iterations: 0.9214351391123144
# Exchange rate after 78800 iterations: 0.9106480761430102
# Exchange rate after 78900 iterations: 0.9158706193979543
# Exchange rate after 79000 iterations: 0.8998844978718087
# Exchange rate after 79100 iterations: 0.8863113255912615
# Exchange rate after 79200 iterations: 0.9035662729606418
# Exchange rate after 79300 iterations: 0.9277543305101806
# Exchange rate after 79400 iterations: 0.928984290326232
# Exchange rate after 79500 iterations: 0.9546957909562755
# Exchange rate after 79600 iterations: 0.9545080849767272
# Exchange rate after 79700 iterations: 0.9591325226164975
# Exchange rate after 79800 iterations: 0.9740413157609141
# Exchange rate after 79900 iterations: 0.9782580287481095
# Exchange rate after 80000 iterations: 0.9847388750709963
# Exchange rate after 80100 iterations: 0.962114757757885
# Exchange rate after 80200 iterations: 0.9955305869764205
# Exchange rate after 80300 iterations: 1.0082227745367272
# Exchange rate after 80400 iterations: 1.0235267181719083
# Exchange rate after 80500 iterations: 0.9903796292935875
# Exchange rate after 80600 iterations: 0.9857963601387217
# Exchange rate after 80700 iterations: 0.988566180617209
# Exchange rate after 80800 iterations: 0.9833854004527346
# Exchange rate after 80900 iterations: 0.9865138884944976
# Exchange rate after 81000 iterations: 0.9728154009599352
# Exchange rate after 81100 iterations: 0.9485894824209921
# Exchange rate after 81200 iterations: 0.9654705998965033
# Exchange rate after 81300 iterations: 0.9636334626404827
# Exchange rate after 81400 iterations: 0.9441475737536973
# Exchange rate after 81500 iterations: 0.968721015540129
# Exchange rate after 81600 iterations: 0.9921071201769024
# Exchange rate after 81700 iterations: 0.993162354828381
# Exchange rate after 81800 iterations: 0.9918819569302358
# Exchange rate after 81900 iterations: 1.0167751990200808
# Exchange rate after 82000 iterations: 1.0447595327373942
# Exchange rate after 82100 iterations: 1.0637491502928031
# Exchange rate after 82200 iterations: 1.0612150383169685
# Exchange rate after 82300 iterations: 1.081211825633272
# Exchange rate after 82400 iterations: 1.0939628709575433
# Exchange rate after 82500 iterations: 1.0357338055927234
# Exchange rate after 82600 iterations: 1.0470560435850178
# Exchange rate after 82700 iterations: 1.0422644022507497
# Exchange rate after 82800 iterations: 1.0165091540117464
# Exchange rate after 82900 iterations: 1.0027141892372329
# Exchange rate after 83000 iterations: 1.0061326431892936
# Exchange rate after 83100 iterations: 1.0185665294729025
# Exchange rate after 83200 iterations: 1.0385086623816557
# Exchange rate after 83300 iterations: 1.064781577465326
# Exchange rate after 83400 iterations: 1.0471811438408511
# Exchange rate after 83500 iterations: 1.0286452629145364
# Exchange rate after 83600 iterations: 1.0315945647902593
# Exchange rate after 83700 iterations: 1.073983386961985
# Exchange rate after 83800 iterations: 1.0648098816471039
# Exchange rate after 83900 iterations: 1.0627054911099716
# Exchange rate after 84000 iterations: 1.068706783047686
# Exchange rate after 84100 iterations: 1.0446254889645168
# Exchange rate after 84200 iterations: 1.0249606307811643
# Exchange rate after 84300 iterations: 1.0163145830900564
# Exchange rate after 84400 iterations: 0.9895363859183751
# Exchange rate after 84500 iterations: 1.00197727300358
# Exchange rate after 84600 iterations: 1.001998173952369
# ...
# Exchange rate after 452400 iterations: 0.9679398853691982
# Exchange rate after 452500 iterations: 0.9497928992221044
# Exchange rate after 452600 iterations: 0.9049695572027026
# Exchange rate after 452700 iterations: 0.8980599968763865
# Exchange rate after 452800 iterations: 0.9003648202415353
# Exchange rate after 452900 iterations: 0.9465108950580438
# Exchange rate after 453000 iterations: 0.9525483239118298
# Exchange rate after 453100 iterations: 0.9872716997622867
# Exchange rate after 453200 iterations: 0.9879598891323099
# Exchange rate after 453300 iterations: 1.0223399882338688
# Exchange rate after 453400 iterations: 1.0059578233783761
# Exchange rate after 453500 iterations: 0.9954212505028399
# Exchange rate after 453600 iterations: 1.0006168414503058
# Exchange rate after 453700 iterations: 0.9888395040961665
# Exchange rate after 453800 iterations: 0.9900528137314059
# Exchange rate after 453900 iterations: 1.0171075972117365
# Exchange rate after 454000 iterations: 1.0250413181108715
# Exchange rate after 454100 iterations: 0.97981794824481
# Exchange rate after 454200 iterations: 0.9941384498596185
# Exchange rate after 454300 iterations: 1.020926888842207
# Exchange rate after 454400 iterations: 1.0007617879309145
# Exchange rate after 454500 iterations: 1.056182916903254
# Exchange rate after 454600 iterations: 1.050272648716332
# Exchange rate after 454700 iterations: 1.0348881101572178
# Exchange rate after 454800 iterations: 1.0462039112761712
# Exchange rate after 454900 iterations: 1.0255004106412517
# Exchange rate after 455000 iterations: 1.0067312056236168
# Exchange rate after 455100 iterations: 0.9710257041917153
# Exchange rate after 455200 iterations: 0.9612200227888832
# Exchange rate after 455300 iterations: 0.9431739424677766
# Exchange rate after 455400 iterations: 0.9301941717017624
# Exchange rate after 455500 iterations: 0.9354625704608439
# Exchange rate after 455600 iterations: 0.969053305106445
# Exchange rate after 455700 iterations: 0.9805206207258707
# Exchange rate after 455800 iterations: 0.9718349363507951
# Exchange rate after 455900 iterations: 0.9611410349597623
# Exchange rate after 456000 iterations: 0.9750781790229888
# Exchange rate after 456100 iterations: 0.9516688889108572
# Exchange rate after 456200 iterations: 0.9505166981630577
# Exchange rate after 456300 iterations: 0.9488317554253165
# Exchange rate after 456400 iterations: 0.9502629331581047
# Exchange rate after 456500 iterations: 0.9534461065683725
# Exchange rate after 456600 iterations: 0.9792235327897347
# Exchange rate after 456700 iterations: 0.9459471088820731
# Exchange rate after 456800 iterations: 0.9371490832887001
# Exchange rate after 456900 iterations: 0.9726248837968751
# Exchange rate after 457000 iterations: 0.958698077061649
# Exchange rate after 457100 iterations: 0.9582590136068768
# Exchange rate after 457200 iterations: 0.9206721307947805
# Exchange rate after 457300 iterations: 0.9485365936833424
# Exchange rate after 457400 iterations: 0.932032405045248
# Exchange rate after 457500 iterations: 0.969923104180817
# Exchange rate after 457600 iterations: 0.9616039452420175
# Exchange rate after 457700 iterations: 0.9792988110711943
# Exchange rate after 457800 iterations: 1.0134331205741727
# Exchange rate after 457900 iterations: 0.9994287900762536
# Exchange rate after 458000 iterations: 1.0353124927196027
# Exchange rate after 458100 iterations: 1.026370108641029
# Exchange rate after 458200 iterations: 1.0273549485516948
# Exchange rate after 458300 iterations: 1.0434351975173939
# Exchange rate after 458400 iterations: 1.024034446079874
# Exchange rate after 458500 iterations: 1.0252844192887938
# Exchange rate after 458600 iterations: 1.0175403413507995
# Exchange rate after 458700 iterations: 1.007253076494095
# Exchange rate after 458800 iterations: 1.0248868714444974
# Exchange rate after 458900 iterations: 1.0394407853075966
# Exchange rate after 459000 iterations: 1.0477968997678129
# Exchange rate after 459100 iterations: 1.021833330435943
# Exchange rate after 459200 iterations: 1.0457998435593387
# Exchange rate after 459300 iterations: 1.0446362349689757
# Exchange rate after 459400 iterations: 1.065113959728906
# Exchange rate after 459500 iterations: 1.0655649425749112
# Exchange rate after 459600 iterations: 1.0447411372061204
# Exchange rate after 459700 iterations: 1.043408367833539
# Exchange rate after 459800 iterations: 1.0391514563312405
# Exchange rate after 459900 iterations: 1.0254519760441845
# Exchange rate after 460000 iterations: 1.024725393515648
# Exchange rate after 460100 iterations: 1.0418378942801363
# Exchange rate after 460200 iterations: 1.041740431329819
# Exchange rate after 460300 iterations: 1.0349944890088059
# Exchange rate after 460400 iterations: 1.0578432302475143
# Exchange rate after 460500 iterations: 1.087744590217913
# Exchange rate after 460600 iterations: 1.0636462668519817
# Exchange rate after 460700 iterations: 1.047204456889269
# Exchange rate after 460800 iterations: 1.0337575727941264
# Exchange rate after 460900 iterations: 1.0434564064634424
# Exchange rate after 461000 iterations: 1.077713226099326
# Exchange rate after 461100 iterations: 1.100344645113457
# Exchange rate after 461200 iterations: 1.095087589356397
# Exchange rate after 461300 iterations: 1.0618362042977392
# Exchange rate after 461400 iterations: 1.0078592866763756
# Exchange rate after 461500 iterations: 0.990217359269435
# Exchange rate after 461600 iterations: 0.9875593752589992
# Exchange rate after 461700 iterations: 1.000822510039862
# Exchange rate after 461800 iterations: 1.0331882399456276
# Exchange rate after 461900 iterations: 0.9835524418487586
# Exchange rate after 462000 iterations: 0.9486506787468677
# Exchange rate after 462100 iterations: 0.9620246553269398
# Exchange rate after 462200 iterations: 0.9849209251452765
# Exchange rate after 462300 iterations: 0.9766358107934774
# Exchange rate after 462400 iterations: 0.9695959156819278
# Exchange rate after 462500 iterations: 0.9253823807162183
# Exchange rate after 462600 iterations: 0.9364995616815252
# Exchange rate after 462700 iterations: 0.9370139631206786
# Exchange rate after 462800 iterations: 0.9507756251566398
# Exchange rate after 462900 iterations: 0.9433386554678076
# Exchange rate after 463000 iterations: 0.9253027043800357
# Exchange rate after 463100 iterations: 0.98365675269013
# Exchange rate after 463200 iterations: 0.9835396123120043
# Exchange rate after 463300 iterations: 0.9789213220778076
# Exchange rate after 463400 iterations: 1.0348946863784454
# Exchange rate after 463500 iterations: 0.9915187871469511
# Exchange rate after 463600 iterations: 0.9714020743603197
# Exchange rate after 463700 iterations: 0.9797912672602201
# Exchange rate after 463800 iterations: 1.0153787389719606
# Exchange rate after 463900 iterations: 1.0011031372041161
# Exchange rate after 464000 iterations: 0.9961881108310274
# Exchange rate after 464100 iterations: 0.9743658674683489
# Exchange rate after 464200 iterations: 0.9754033060678678
# Exchange rate after 464300 iterations: 1.0057742336408473
# Exchange rate after 464400 iterations: 0.9946645277883095
# Exchange rate after 464500 iterations: 0.9939168346929279
# Exchange rate after 464600 iterations: 1.0432985574100995
# Exchange rate after 464700 iterations: 1.0446019351992484
# Exchange rate after 464800 iterations: 1.0459753231213929
# Exchange rate after 464900 iterations: 1.0771269067306606
# Exchange rate after 465000 iterations: 1.0790565848103995
# Exchange rate after 465100 iterations: 1.1233731088151735
# Exchange rate after 465200 iterations: 1.079317313552906
# Exchange rate after 465300 iterations: 1.0738375650509233
# Exchange rate after 465400 iterations: 1.0708382531791647
# Exchange rate after 465500 iterations: 1.0751416186698732
# Exchange rate after 465600 iterations: 1.0676868894180291
# Exchange rate after 465700 iterations: 1.056176156857645
# Exchange rate after 465800 iterations: 1.070062110862458
# Exchange rate after 465900 iterations: 1.0891584963973335
# Exchange rate after 466000 iterations: 1.104590019863118
# Exchange rate after 466100 iterations: 1.0883609950026796
# Exchange rate after 466200 iterations: 1.0714748063254602
# Exchange rate after 466300 iterations: 1.056740735975626
# Exchange rate after 466400 iterations: 1.0865308692710407
# Exchange rate after 466500 iterations: 1.0378655922825706
# Exchange rate after 466600 iterations: 1.0630966013413474
# Exchange rate after 466700 iterations: 1.0249903674329142
# Exchange rate after 466800 iterations: 1.0173408563505826
# Exchange rate after 466900 iterations: 1.0285391136391542
# Exchange rate after 467000 iterations: 1.012565824322335
# Exchange rate after 467100 iterations: 0.9951319541262853
# Exchange rate after 467200 iterations: 0.9901463688121488
# Exchange rate after 467300 iterations: 1.0343524504807002
# Exchange rate after 467400 iterations: 0.9968030285614745
# Exchange rate after 467500 iterations: 0.9836564674291415
# Exchange rate after 467600 iterations: 1.0046447036989157
# Exchange rate after 467700 iterations: 1.0213137936837589
# Exchange rate after 467800 iterations: 0.982258796453567
# Exchange rate after 467900 iterations: 0.9698357810236232
# Exchange rate after 468000 iterations: 1.0268203385228718
# Exchange rate after 468100 iterations: 0.9846328949346163
# Exchange rate after 468200 iterations: 0.9816212911491866
# Exchange rate after 468300 iterations: 1.0007892686135471
# Exchange rate after 468400 iterations: 0.9924548068947399
# Exchange rate after 468500 iterations: 1.0339532341765973
# Exchange rate after 468600 iterations: 1.0153377793604732
# Exchange rate after 468700 iterations: 1.0107085655011339
# Exchange rate after 468800 iterations: 1.0237543073843567
# Exchange rate after 468900 iterations: 1.0415470128075044
# Exchange rate after 469000 iterations: 1.0433123550583694
# Exchange rate after 469100 iterations: 1.0156596557793651
# Exchange rate after 469200 iterations: 1.0041116104420305
# Exchange rate after 469300 iterations: 1.0142179963895694
# Exchange rate after 469400 iterations: 1.0376382865323563
# Exchange rate after 469500 iterations: 1.0818233325780238
# Exchange rate after 469600 iterations: 1.0898304201636968
# Exchange rate after 469700 iterations: 1.0415523204053427
# Exchange rate after 469800 iterations: 1.0113125724670349
# Exchange rate after 469900 iterations: 1.0429304329007567
# Exchange rate after 470000 iterations: 1.0273865823806823
# Exchange rate after 470100 iterations: 1.0359482268027307
# Exchange rate after 470200 iterations: 0.9975334316540948
# Exchange rate after 470300 iterations: 0.9687990886092669
# Exchange rate after 470400 iterations: 0.9519432797741922
# Exchange rate after 470500 iterations: 0.956447398643175
# Exchange rate after 470600 iterations: 0.9724921800667108
# Exchange rate after 470700 iterations: 0.9523202223065793
# Exchange rate after 470800 iterations: 0.9523723096411225
# Exchange rate after 470900 iterations: 0.9401854330768692
# Exchange rate after 471000 iterations: 0.941544885437563
# Exchange rate after 471100 iterations: 0.9559653456195566
# Exchange rate after 471200 iterations: 0.998353722489039
# Exchange rate after 471300 iterations: 0.9986202027574261
# Exchange rate after 471400 iterations: 0.9841369482181166
# Exchange rate after 471500 iterations: 1.0048853226887766
# Exchange rate after 471600 iterations: 1.0229554474994795
# Exchange rate after 471700 iterations: 1.0018140905907122
# Exchange rate after 471800 iterations: 0.981207306821815
# Exchange rate after 471900 iterations: 0.9682442877485561
# Exchange rate after 472000 iterations: 0.9428863027071097
# Exchange rate after 472100 iterations: 0.9305970349308761
# Exchange rate after 472200 iterations: 0.9817716037958388
# Exchange rate after 472300 iterations: 1.0070121087768749
# Exchange rate after 472400 iterations: 1.0154744727209721
# Exchange rate after 472500 iterations: 0.9932189914201696
# Exchange rate after 472600 iterations: 0.9829089840919292
# Exchange rate after 472700 iterations: 1.025988253496557
# Exchange rate after 472800 iterations: 1.0419841126679672
# Exchange rate after 472900 iterations: 1.0544254456573738
# Exchange rate after 473000 iterations: 1.0710568325056506
# Exchange rate after 473100 iterations: 1.0687644388480864
# Exchange rate after 473200 iterations: 1.0528465397769513
# Exchange rate after 473300 iterations: 1.0709091069936825
# Exchange rate after 473400 iterations: 1.0695958321200278
# Exchange rate after 473500 iterations: 1.0200986853210618
# Exchange rate after 473600 iterations: 1.0139609295819925
# Exchange rate after 473700 iterations: 1.0391409039868698
# Exchange rate after 473800 iterations: 0.9997271584013102
# Exchange rate after 473900 iterations: 0.9911621104214187
# Exchange rate after 474000 iterations: 0.9845209038547892
# Exchange rate after 474100 iterations: 1.0104632767320454
# Exchange rate after 474200 iterations: 0.9923746315795487
# Exchange rate after 474300 iterations: 0.9632997886734374
# Exchange rate after 474400 iterations: 0.9569143920161629
# Exchange rate after 474500 iterations: 0.9765993111406639
# Exchange rate after 474600 iterations: 0.9728656244685371
# Exchange rate after 474700 iterations: 0.972131729738024
# Exchange rate after 474800 iterations: 0.9884360321498383
# Exchange rate after 474900 iterations: 0.9865367304625293
# Exchange rate after 475000 iterations: 0.9627940145994377
# Exchange rate after 475100 iterations: 0.9612539255615011
# Exchange rate after 475200 iterations: 0.9128988939617348
# Exchange rate after 475300 iterations: 0.8958475752615154
# Exchange rate after 475400 iterations: 0.9098681948144944
# Exchange rate after 475500 iterations: 0.9429800306477587
# Exchange rate after 475600 iterations: 0.9356336767819433
# Exchange rate after 475700 iterations: 0.9372155986916192
# Exchange rate after 475800 iterations: 0.900004114811459
# Exchange rate after 475900 iterations: 0.8833791420679713
# Exchange rate after 476000 iterations: 0.8777618420521246
# Exchange rate after 476100 iterations: 0.8561563170019586
# Exchange rate after 476200 iterations: 0.843731912068086
# Exchange rate after 476300 iterations: 0.8271921819261469
# Exchange rate after 476400 iterations: 0.8357779380209831
# Exchange rate after 476500 iterations: 0.871262793223978
# Exchange rate after 476600 iterations: 0.8482262026462967
# Exchange rate after 476700 iterations: 0.8562541591896147
# Exchange rate after 476800 iterations: 0.8822678490745872
# Exchange rate after 476900 iterations: 0.8565366147107126
# Exchange rate after 477000 iterations: 0.8883573336325664
# Exchange rate after 477100 iterations: 0.8853967945399265
# Exchange rate after 477200 iterations: 0.8994149543308879
# Exchange rate after 477300 iterations: 0.9128696948834701
# Exchange rate after 477400 iterations: 0.9399266177412653
# Exchange rate after 477500 iterations: 0.9673251941066192
# Exchange rate after 477600 iterations: 0.9951595500676454
# Exchange rate after 477700 iterations: 1.0552649343645242
# Exchange rate after 477800 iterations: 1.0949516471280043
# Exchange rate after 477900 iterations: 1.0791031500794845
# Exchange rate after 478000 iterations: 1.0667507584399398
# Exchange rate after 478100 iterations: 1.0600337777839386
# Exchange rate after 478200 iterations: 1.106739421393382
# Exchange rate after 478300 iterations: 1.0771935385663975
# Exchange rate after 478400 iterations: 1.0663058197609139
# Exchange rate after 478500 iterations: 1.0738351137464506
# Exchange rate after 478600 iterations: 1.0258826443855298
# Exchange rate after 478700 iterations: 1.0297266730710035
# Exchange rate after 478800 iterations: 1.0050970655694342
# Exchange rate after 478900 iterations: 0.9990221275588547
# Exchange rate after 479000 iterations: 1.0041140787419716
# Exchange rate after 479100 iterations: 0.9970811215940615
# Exchange rate after 479200 iterations: 0.9911435331956014
# Exchange rate after 479300 iterations: 0.9919073292958899
# Exchange rate after 479400 iterations: 1.0150302169334355
# Exchange rate after 479500 iterations: 0.9992930134492368
# Exchange rate after 479600 iterations: 0.9864394241805494
# Exchange rate after 479700 iterations: 0.9768822512228872
# Exchange rate after 479800 iterations: 0.9857304183549328
# Exchange rate after 479900 iterations: 1.0002650835654951

# %%
# 0.3% fee on all trades
print("Fees Collected A:", round(np.mean(feesA), 2))
print("Fees Collected B:", round(np.mean(feesB), 2))
print("Percentage A:", round(np.mean(ratiosA), 4))
print("Percentage B:", round(np.mean(ratiosB), 4))
print("Pool Volatility:", round(np.mean(vols), 2), "%")
# Out:
# Fees Collected A: 296.14
# Fees Collected B: 296.41
# Percentage A: 0.5821
# Percentage B: 0.5827
# Pool Volatility: 4.86 %

# %%
# Tiered Fees
print("Fees Collected A:", round(np.mean(feesA), 2))
print("Fees Collected B:", round(np.mean(feesB), 2))
print("Percentage A:", round(np.mean(ratiosA), 4))
print("Percentage B:", round(np.mean(ratiosB), 4))
print("Pool Volatility:", round(np.mean(vols), 2), "%")
# Out:
# Fees Collected A: -469.46
# Fees Collected B: -472.21
# Percentage A: -0.4078
# Percentage B: -0.4101
# Pool Volatility: 11.89 %

# %%
# Inverse Tiered Fees
print("Fees Collected A:", round(np.mean(feesA), 2))
print("Fees Collected B:", round(np.mean(feesB), 2))
print("Ratio A:", round(np.mean(ratiosA), 4))
print("Ratio B:", round(np.mean(ratiosB), 4))
print("Pool Volatility:", round(np.mean(vols), 2), "%")
# Out:
# Fees Collected A: 504.4
# Fees Collected B: 504.86
# Ratio A: 0.5798
# Ratio B: 0.5807
# Pool Volatility: 8.48 %

# %%
# Triangle Fees
print(fees_collected["FA"])
print("Fees Collected A:", round(np.mean(feesA), 2))
print("Fees Collected B:", round(np.mean(feesB), 2))
print("Ratio A:", round(np.mean(ratiosA), 4))
print("Ratio B:", round(np.mean(ratiosB), 4))
print("Pool Volatility:", round(np.mean(vols), 2), "%")
# Out:
# 15.063000000000459
# Fees Collected A: 321.94
# Fees Collected B: 326.08
# Ratio A: 0.6332
# Ratio B: 0.6417
# Pool Volatility: 4.88 %

# %%
plt.bar(["Percentage Fees", "Tiered Fees", "Naive Triangle Fees", "Triangle Fees"], 
        [296.14, 469.24, 504.4, 325.53])
plt.title("Fees Collected Using Different Fee Structures")
# Out:
# Text(0.5, 1.0, 'Fees Collected Using Different Fee Structures')

# %%
plt.bar(["Percentage Fees", "Tiered Fees", "Naive Triangle Fees", "Triangle Fees"], 
        [0.5821, 0.4021, 0.5798, 0.6421])
plt.title("Risk Adjusted Scores of Each Fee Structure")
# Out:
# Text(0.5, 1.0, 'Risk Adjusted Scores of Each Fee Structure')

# %%
plt.bar(["Percentage Fees", "Tiered Fees", "Naive Triangle Fees", "Triangle Fees"], 
        [4.86, 11.31, 8.48, 4.84])
plt.title("Percent Pool Volatility for Each Fee Structure")
# Out:
# Text(0.5, 1.0, 'Percent Pool Volatility for Each Fee Structure')
